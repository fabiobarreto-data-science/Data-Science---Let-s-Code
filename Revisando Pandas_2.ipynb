# %%
import pandas as pd

# %%
df_titanic = pd.read_csv('C:\\Users\\Fabio\\Desktop\\Data Science\\Módulo 3\\Aula Pandas\\titanic.csv')
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_titanic.shape
# Out:
# (891, 12)

# %%
name = df_titanic[df_titanic["Name"] == "Heikkinen, Miss. Laina"]

# %%
name
# Out:
#    PassengerId  Survived  Pclass                    Name     Sex   Age  SibSp  \
# 2            3         1       3  Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 2      0  STON/O2. 3101282  7.925   NaN        S

# %%
colunas = ["Pclass", "Name", "Age", "Ticket"]

# %%
df_titanic2 = pd.read_csv('C:\\Users\\Fabio\\Desktop\\Data Science\\Módulo 3\\Aula Pandas\\titanic.csv', index_col=3, usecols=colunas, nrows=10)

# %%
df_titanic2
# Out:
#                   Pclass                                               Name  \
# Ticket
# A/5 21171              3                            Braund, Mr. Owen Harris
# PC 17599               1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# STON/O2. 3101282       3                             Heikkinen, Miss. Laina
# 113803                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 373450                 3                           Allen, Mr. William Henry
# 330877                 3                                   Moran, Mr. James
# 17463                  1                            McCarthy, Mr. Timothy J
# 349909                 3                     Palsson, Master. Gosta Leonard
# 347742                 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 237736                 2                Nasser, Mrs. Nicholas (Adele Achem)
#
#                    Age
# Ticket
# A/5 21171         22.0
# PC 17599          38.0
# STON/O2. 3101282  26.0
# ...

# %%
df_titanic3 = pd.read_csv('C:\\Users\\Fabio\\Desktop\\Data Science\\Módulo 3\\Aula Pandas\\titanic.csv', chunksize=100)

# %%
df_titanic3

# %%
for people in df_titanic3:
    print(people)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
df1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)


df2 = pd.DataFrame(
    {
        "A": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
        "C": ["C4", "C5", "C6", "C7"],
        "D": ["D4", "D5", "D6", "D7"],
    },
    index=[4, 5, 6, 7],
)


df3 = pd.DataFrame(
    {
        "A": ["A8", "A9", "A10", "A11"],
        "B": ["B8", "B9", "B10", "B11"],
        "C": ["C8", "C9", "C10", "C11"],
        "D": ["D8", "D9", "D10", "D11"],
    },
    index=[8, 9, 10, 11],
)

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df3, df2], keys=["DataFrame 1", "DataFrame 2"])
# Out:
#                   A    B    C    D
# DataFrame 1 8    A8   B8   C8   D8
#             9    A9   B9   C9   D9
#             10  A10  B10  C10  D10
#             11  A11  B11  C11  D11
# DataFrame 2 4    A4   B4   C4   D4
#             5    A5   B5   C5   D5
#             6    A6   B6   C6   D6
#             7    A7   B7   C7   D7

# %%
df4 = pd.concat([df1, df2, df3], keys=["A", "B", "C"])

# %%
df4
# Out:
#         A    B    C    D
# A 0    A0   B0   C0   D0
#   1    A1   B1   C1   D1
#   2    A2   B2   C2   D2
#   3    A3   B3   C3   D3
# B 4    A4   B4   C4   D4
#   5    A5   B5   C5   D5
#   6    A6   B6   C6   D6
#   7    A7   B7   C7   D7
# C 8    A8   B8   C8   D8
#   9    A9   B9   C9   D9
#   10  A10  B10  C10  D10
#   11  A11  B11  C11  D11

# %%
df4.loc["A"].loc[1]
# Out:
# A    A1
# B    B1
# C    C1
# D    D1
# Name: 1, dtype: object

# %%
df4[["A", "B"]] # Pego colunas
# Out:
#         A    B
# A 0    A0   B0
#   1    A1   B1
#   2    A2   B2
#   3    A3   B3
# B 4    A4   B4
#   5    A5   B5
#   6    A6   B6
#   7    A7   B7
# C 8    A8   B8
#   9    A9   B9
#   10  A10  B10
#   11  A11  B11

# %%
df4.loc[["A", "B"]] # Pego as linhas
# Out:
#       A   B   C   D
# A 0  A0  B0  C0  D0
#   1  A1  B1  C1  D1
#   2  A2  B2  C2  D2
#   3  A3  B3  C3  D3
# B 4  A4  B4  C4  D4
#   5  A5  B5  C5  D5
#   6  A6  B6  C6  D6
#   7  A7  B7  C7  D7

# %%
df5 = pd.concat([df1, df3], axis=1)

# %%
df5
# Out:
#       A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
df5["X"] = ["X1", "X2", "X3", "X4", "X5", "X6", "X7", "X8"]
df5
# Out:
#       A    B    C    D    A    B    C    D   X
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  X1
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  X2
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  X3
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  X4
# 8   NaN  NaN  NaN  NaN   A8   B8   C8   D8  X5
# 9   NaN  NaN  NaN  NaN   A9   B9   C9   D9  X6
# 10  NaN  NaN  NaN  NaN  A10  B10  C10  D10  X7
# 11  NaN  NaN  NaN  NaN  A11  B11  C11  D11  X8

# %%
juntando = df1.append(df2)

# %%
juntando
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
juntando = juntando.append(df3)

# %%
juntando
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df_esquerda = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K3"],
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
    }
)


df_direita = pd.DataFrame(
    {
        "key": ["K3", "K1", "K2", "K0"],
        "C": ["C3", "C1", "C2", "C0"],
        "D": ["D3", "D1", "D2", "D0"],
    }
)

# %%
df_esquerda
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
df_direita
# Out:
#   key   C   D
# 0  K3  C3  D3
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K0  C0  D0

# %%
df7 = pd.merge(left=df_esquerda, right=df_direita)

# %%
df7
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
df7.rename(columns={"key": "Índice"})
# Out:
#   Índice   A   B   C   D
# 0     K0  A0  B0  C0  D0
# 1     K1  A1  B1  C1  D1
# 2     K2  A2  B2  C2  D2
# 3     K3  A3  B3  C3  D3

# %%
df_titanic['Age_processada'] = df_titanic['Age'].apply(lambda idade: True if(idade>=12) else False)
df_titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Age_processada
# 0      0  A/5 21171   7.2500   NaN        S            True
# 1      0   PC 17599  71.2833   C85        C            True

# %%
df_titanic["Idade_processada"] = df_titanic["Age"].apply(lambda idade: True if (idade <12) else False)

# %%
df_adolescentes_sobreviventes = df_titanic[(df_titanic["Age"] > 12) & (df_titanic["Age"] < 20) & ((df_titanic["Survived"] == 1))]

# %%
df_adolescentes_sobreviventes.shape
# Out:
# (39, 13)

# %%
df_titanic_agrupado = df_titanic.groupby(by=["Survived", "Pclass"])["Age"].value_counts()

# %%
df_titanic_agrupado.head()
# Out:
# Survived  Pclass  Age
# 0         1       47.0    4
#                   45.0    3
#                   50.0    3
#                   19.0    2
#                   24.0    2
# Name: Age, dtype: int64
